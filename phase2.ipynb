# %%
import pandas as pd
data={'Name':['shank','ram'],'Dept':['cse','eee']}

# %%
df=pd.DataFrame(data)
print(df['Name'])
# Out:
# 0    shank
# 1      ram
# Name: Name, dtype: object

# %%
df1=df=pd.DataFrame({"a":[1,2,3,4],"b":[5,6,7,8]})
df2=df=pd.DataFrame({"a":[11,12,13,14],"b":[15,16,17,18]})
print("dataframe1")
print(df1,"\n")
print(df2,"\n")
result=pd.concat([df1,df2])
print(result)
# Out:
# dataframe1
#    a  b
# 0  1  5
# 1  2  6
# 2  3  7
# 3  4  8
#
#     a   b
# 0  11  15
# 1  12  16
# 2  13  17
# 3  14  18
#
#     a   b
# 0   1   5
# 1   2   6
# 2   3   7
# 3   4   8
# 0  11  15
# 1  12  16
# 2  13  17
# 3  14  18

# %%
from datetime import date
d=date(2024,4,4)
print(d)
print(type(d))
# Out:
# 2024-04-04
# <class 'datetime.date'>

# %%
from datetime import time
t=time(11,50,11,50)
print(t)
print(type(t))
# Out:
# 11:50:11.000050
# <class 'datetime.time'>

# %%
import pandas as pd
dataset=pd.read_csv("housing_prices_SLR.csv")
print(dataset.index)
dataset.drop([2],inplace=True)
print(dataset)
# Out:
# RangeIndex(start=0, stop=50, step=1)
#     AREA  PRICE
# 0   1000   5618
# 1   1030   5201
# 3   1090   5425
# 4   1120   5657
# 5   1150   4945
# 6   1180   6475
# 7   1210   5352
# 8   1240   6290
# 9   1270   6147
# 10  1300   7718
# 11  1330   7035
# 12  1360   8712
# 13  1390   9457
# 14  1420   7304
# 15  1450   7535
# 16  1480   9968
# 17  1510   7614
# 18  1540   9762
# 19  1570  10067
# 20  1600   8074
# 21  1630  10201
# 22  1660  10051
# 23  1690   9775
# 24  1720  10229
# 25  1750   8314
# 26  1780   9288
# 27  1810  10503
# 28  1840   9763
# 29  1870  11527
# 30  1900   9912
# 31  1930  10204
# 32  1960   9085
# 33  1990  10240
# 34  2020  15220
# 35  2050  12278
# 36  2080  22270
# 37  2110  12574
# 38  2140  12618
# 39  2170  15457
# 40  2200  12793
# 41  2230  12641
# 42  2260  17207
# 43  2290  16969
# 44  2320  16293
# 45  2350  16845
# 46  2380  17604
# 47  2410  17310
# 48  2440  14036
# 49  2470  13699

# %%
dataset.plot.line(subplots=True)
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
import matplotlib.pyplot as plt
import pandas as pd
value_counts = dataset['AREA'].value_counts()
value_counts.plot.bar()
plt.show()

# %%
dataset.boxplot(column=['PRICE'],by='PRICE')
# Out:
# <Axes: title={'center': 'PRICE'}, xlabel='PRICE'>

# %%
''
# Out:
# <Axes: title={'center': 'PRICE'}, xlabel='PRICE'>

# %%
plt.plot(dataset['AREA'],dataset['AREA'],label='AREA')
plt.plot(dataset['PRICE'],dataset['PRICE'],label='PRICE')
plt.legend()
plt.show()
